# %%
# Convert abbreviations in Company names from the spreadsheet for accurate Factiva Search

AbbrevDict = {    
    'sec':'security', 
    'grp':'group',  
    'finl':'financial',
    'co':'company',
    'bkg':'banking',
    'hldg':'holdings',
    'natl':'national',
    'gen':'general',    
    'svcs':'services',
    'bk':'bank',
    'ca':'california',
    'pac':'pacific',
    'ny':'new york',
    'sthrn':'southern',
    'tr':'trust',
    'cmnty':'community',
    'fed':'federal',      #bank abbreviations ^
    'resh':'research',    #non-bank abbreviations 
    'cp': 'corp',    
    'intl':'international',    
    'mun ': 'municipal',
    'opp': 'opportunity',    
    'eqty': 'equity',
    'cp': 'corp',
    'capitl': 'capital',
    'serv': 'services',
    'infastcr': 'infastructure',        
    'egy':'energy',
    'fiduciary/claymr':'fiduciary/claymore',
    'infr':'infrastructure',
    'conv': 'convertible',
    'invst':'investment',
    'mgmt':'management',
    'dividnd':'dividend',
    '-adr':'',
    '-cl': '',
    'hldgs':'holdings',
    'rlty':'realty',
    'netwk':'network',
    'pptys':'properties',
    'sust':'sustainable'
}

AbbrevDict2 = {
    'inc':'income',    
    'r':'real',
    'e':'estate',    
    'a':'',
    'fd': '',        
    'opportunity':'opportunities',
    '&':'and', 
    '(j c)': '',
    'trust': 'total return'
}

#abbreviations that don't need correcting:

# 'bancorp':'bancorporation',
#    'corp':'corporation',

# Bank Name Stop Words

# This file filters stop words in banks only within headline search. 
# For example, "Huntington Bancshares Inc" becomes "Huntington"

bank_stop_words = {    
    'group',      
    'company',
    'banking',
    'holdings',        
    'bancorp',
    'bancorporation',
    'corp',
    'corporation',
    'services',
    'bank',    
    'bancshares',    
    'inc'        
}
